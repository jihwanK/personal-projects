# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics.pairwise import cosine_similarity
import dgl
from dgl.nn import GATConv

# %%
import os
import pandas as pd
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# if device == "cpu":
#     print("device CPU")
#     exit(0)

# %%
DATA_HOME = "/lyceum/jhk1c21/msc_project/data"
V14_PATH = os.path.join(DATA_HOME, "graph", "v14")
FILTERED_PATH = os.path.join(V14_PATH, "filtered")

# %%
nodes = pd.read_csv(os.path.join(V14_PATH, "nodes_v14.csv"), index_col='id')

# %%
# Load the data
titles = np.load(os.path.join(FILTERED_PATH, 'title_embedding.npy'))
abstracts = np.load(os.path.join(FILTERED_PATH, 'abstract_embedding.npy'))
keywords = np.load(os.path.join(FILTERED_PATH, 'keywords_embedding.npy'))
domains = np.load(os.path.join(FILTERED_PATH, 'domains_embedding.npy'))

ids = np.load(os.path.join(FILTERED_PATH, "filtered_id.npy"))
edges = np.load(os.path.join(FILTERED_PATH, 'filtered_edge.npy'))

# %%
df = pd.DataFrame()
df['src'] = edges[:, 0]
df['dst'] = edges[:, 1]

# convert id from str to numbers
id_to_int = {original_id: i for i, original_id in enumerate(ids)}
int_to_id = {i: original_id for original_id, i in id_to_int.items()}

df['src'] = df['src'].apply(lambda x: id_to_int[x])
df['dst'] = df['dst'].apply(lambda x: id_to_int[x])

# %%
# Compute similarity for titles, abstracts, keywords, and domains
def compute_similarity(node1, node2):
    title_similarity = cosine_similarity([node1['title']], [node2['title']])[0][0]
    abstract_similarity = cosine_similarity([node1['abstract']], [node2['abstract']])[0][0]
    keyword_similarity = cosine_similarity([node1['keywords']], [node2['keywords']])[0][0]
    domain_dissimilarity = 1 - cosine_similarity([node1['domain']], [node2['domain']])[0][0]

    return title_similarity, abstract_similarity, keyword_similarity, domain_dissimilarity


# Compute similarity for titles, abstracts, keywords, and domains
def compute_hetro_similarity(node1, node2):
    title_similarity, abstract_similarity, keyword_similarity, domain_dissimilarity = compute_similarity(node1, node2)
    w1, w2, w3, w4 = 0.25, 0.15, 0.2, 0.4

    # return title_similarity + abstract_similarity + keyword_similarity - domain_dissimilarity
    return w1*title_similarity + w2*abstract_similarity + w3*keyword_similarity - w4*domain_dissimilarity


# Compute similarity for titles, abstracts, keywords
def compute_homo_similarity(node1, node2):
    title_similarity, abstract_similarity, keyword_similarity, domain_dissimilarity = compute_similarity(node1, node2)
    w1, w2, w3 = 0.4, 0.3, 0.35

    return w1*title_similarity + w2*abstract_similarity + w3*keyword_similarity

def normalise(similarity, mean, std):
    normalised_title_similarity = (similarity['title'] - mean.loc['title']['mean']) / std.loc['title']['std']
    normalised_abstract_similarity = (similarity['abstract'] - mean.loc['abstract']['mean']) / std.loc['abstract']['std']
    normalised_keyword_similarity = (similarity['keyword'] - mean.loc['keyword']['mean']) / std.loc['keyword']['std']
    normalised_domain_similarity = (1-similarity['domain'] - mean.loc['domain']['mean']) / std.loc['domain']['std']
    
    return normalised_title_similarity, normalised_abstract_similarity, normalised_keyword_similarity, normalised_domain_similarity

# %%
# Initialize lists to hold pairs and labels
pairs = []
labels = []
weights = []

# Loop over edges in the graph to create pairs and labels
src_list, dst_list = list(df['src']), list(df['dst'])
for idx, (src, dst) in enumerate(zip(src_list, dst_list)):
    node1 = {'title': titles[src], 'abstract': abstracts[src], 'keywords': keywords[src], 'domain': domains[src]}
    node2 = {'title': titles[dst], 'abstract': abstracts[dst], 'keywords': keywords[dst], 'domain': domains[dst]}

    title_similarity, abstract_similarity, keyword_similarity, domain_dissimilarity = compute_similarity(node1, node2)
    hetro_similarity = compute_hetro_similarity(node1, node2)
    homo_similarity = compute_homo_similarity(node1, node2)

    # if similarity > 0.5:
    #     labels.append(0)
    # else:
    #     labels.append(1)

    # pairs.append((src, dst))
    # weights.append(similarity)
    # print(f"{nodes.loc[src]['title']}-{nodes.loc[dst]['title']}: {similarity}")
    
    if idx % 10000 == 0:
        print(idx)
    
    if domain_dissimilarity > 0.2:
        print(f"HETRO: [{hetro_similarity}]")
        print(f"HOMO: [{homo_similarity}]")
        print(f"[{title_similarity}, {abstract_similarity}, {keyword_similarity}, {1-domain_dissimilarity}]")
        print(f"SRC: {nodes.loc[int_to_id[src]]['fos']}\nDST: {nodes.loc[int_to_id[dst]]['fos']}\n")
        print(f"SRC: {nodes.loc[int_to_id[src]]['title']}\nDST: {nodes.loc[int_to_id[dst]]['title']}\n")

# Convert pairs and labels to tensors
pairs = torch.LongTensor(pairs)
labels = torch.FloatTensor(labels)
weights = torch.FloatTensor(weights)
# Out:
# 0
# 10000
# 20000
# 30000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 12
#       9 node1 = {'title': titles[src], 'abstract': abstracts[src], 'keywords': keywords[src], 'domain': domains[src]}
#      10 node2 = {'title': titles[dst], 'abstract': abstracts[dst], 'keywords': keywords[dst], 'domain': domains[dst]}
# ---> 12 title_similarity, abstract_similarity, keyword_similarity, domain_dissimilarity = compute_similarity(node1, node2)
#      13 hetro_similarity = compute_hetro_similarity(node1, node2)
#      14 homo_similarity = compute_homo_similarity(node1, node2)
#
# Cell In[29], line 3, in compute_similarity(node1, node2)
#       2 def compute_similarity(node1, node2):
# ----> 3     title_similarity = cosine_similarity([node1['title']], [node2['title']])[0][0]
#       4     abstract_similarity = cosine_similarity([node1['abstract']], [node2['abstract']])[0][0]
#       5     keyword_similarity = cosine_similarity([node1['keywords']], [node2['keywords']])[0][0]
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1577, in cosine_similarity(X, Y, dense_output)
#    1542 """Compute cosine similarity between samples in X and Y.
#    1543
#    1544 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1573     Returns the cosine similarity between samples in X and Y.
#    1574 """
#    1575 # to avoid recursive import
# -> 1577 X, Y = check_pairwise_arrays(X, Y)
#    1579 X_normalized = normalize(X, copy=True)
#    1580 if X is Y:
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:173, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     164 else:
#     165     X = check_array(
#     166         X,
#     167         accept_sparse=accept_sparse,
#    (...)
#     171         estimator=estimator,
#     172     )
# --> 173     Y = check_array(
#     174         Y,
#     175         accept_sparse=accept_sparse,
#     176         dtype=dtype,
#     177         copy=copy,
#     178         force_all_finite=force_all_finite,
#     179         estimator=estimator,
#     180     )
#     182 if precomputed:
#     183     if X.shape[1] != Y.shape[0]:
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/utils/validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     115 # First try an O(n) time, O(1) space solution for the common case that
#     116 # everything is finite; fall back to O(n) space `np.isinf/isnan` or custom
#     117 # Cython implementation to prevent false positives and provide a detailed
#     118 # error message.
#     119 with np.errstate(over="ignore"):
# --> 120     first_pass_isfinite = xp.isfinite(xp.sum(X))
#     121 if first_pass_isfinite:
#     122     return
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/utils/_array_api.py:227, in _NumPyAPIWrapper.__getattr__(self, name)
#     210 # Data types in spec
#     211 # https://data-apis.org/array-api/latest/API_specification/data_types.html
#     212 _DTYPES = {
#     213     "int8",
#     214     "int16",
#    (...)
#     224     "complex128",
#     225 }
# --> 227 def __getattr__(self, name):
#     228     attr = getattr(numpy, name)
#     230     # Support device kwargs and make sure they are on the CPU
#
# KeyboardInterrupt:

# %%
# Out:
#                             std
# NaN                         std
# title       0.13983675837516785
# abstract    0.19557268917560577
# keyword     0.17731449007987976
# domain    0.0038095359192745616

# %%
mean_for_normalise = pd.read_csv(os.path.join(FILTERED_PATH, "mean.csv"), index_col=0)
std_for_normalise = pd.read_csv(os.path.join(FILTERED_PATH, "std.csv"), index_col=0)

# normalise only in terms of edges
src_list, dst_list = list(df['src']), list(df['dst'])
for idx, (src, dst) in enumerate(zip(src_list, dst_list)):
    node1 = {'title': titles[src], 'abstract': abstracts[src], 'keywords': keywords[src], 'domain': domains[src]}
    node2 = {'title': titles[dst], 'abstract': abstracts[dst], 'keywords': keywords[dst], 'domain': domains[dst]}
    similarity = {}
    similarity['title'], similarity['abstract'], similarity['keyword'], similarity['domain'] = compute_similarity(node1, node2)
    # domain_similarity = 1- domain_dissimilarity
    
    if idx % 10000 == 0:
        print(idx)

    
    normalised_title_similarity, normalised_abstract_similarity, normalised_keyword_similarity, normalised_domain_similarity = normalise(similarity, mean_for_normalise, std_for_normalise)
    
    
    print(f"[title] {normalised_title_similarity}")
    print(f"[abstract] {normalised_abstract_similarity}")
    print(f"[keyword] {normalised_keyword_similarity}")
    print(f"[domain] {normalised_domain_similarity}")
# Out:
# 0
# [title] 0.27802861080747127
# [abstract] -1.1899947739602574
# [keyword] -1.5645928937102074
# [domain] 0.6681886071528401
# [title] 0.8244791345873307
# [abstract] -1.5190685687043657
# [keyword] -2.618643972363589
# [domain] -0.852462608238101
# [title] -0.6346332581935379
# [abstract] -1.0074776026596044
# [keyword] 0.031240298859419
# [domain] 0.5237275239991765
# [title] -0.9079128662532241
# [abstract] 0.30495172408643556
# [keyword] 0.8951875955827595
# [domain] 0.9234871551673888
# [title] 0.318337697721489
# [abstract] -0.6608990510307279
# [keyword] -0.44569470629295305
# [domain] -0.6067082236291339
# [title] -0.1521454056280894
# [abstract] -0.7379277834299875
# [keyword] 0.8880248658458842
# [domain] -0.6699343946487326
# [title] -0.6224861433251291
# [abstract] 0.8206340719962218
# [keyword] 0.9327418400329297
# [domain] 0.20440485031964456
# [title] -0.9210418352552345
# [abstract] 1.5502648030299608
# [keyword] 1.1088116063920677
# [domain] 1.2398996413166943
# [title] -0.6131347659267846
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 10
#       8 node2 = {'title': titles[dst], 'abstract': abstracts[dst], 'keywords': keywords[dst], 'domain': domains[dst]}
#       9 similarity = {}
# ---> 10 similarity['title'], similarity['abstract'], similarity['keyword'], similarity['domain'] = compute_similarity(node1, node2)
#      11 # domain_similarity = 1- domain_dissimilarity
#      13 if idx % 10000 == 0:
#
# Cell In[28], line 4, in compute_similarity(node1, node2)
#       2 def compute_similarity(node1, node2):
#       3     title_similarity = cosine_similarity([node1['title']], [node2['title']])[0][0]
# ----> 4     abstract_similarity = cosine_similarity([node1['abstract']], [node2['abstract']])[0][0]
#       5     keyword_similarity = cosine_similarity([node1['keywords']], [node2['keywords']])[0][0]
#       6     domain_dissimilarity = 1 - cosine_similarity([node1['domain']], [node2['domain']])[0][0]
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:1577, in cosine_similarity(X, Y, dense_output)
#    1542 """Compute cosine similarity between samples in X and Y.
#    1543
#    1544 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1573     Returns the cosine similarity between samples in X and Y.
#    1574 """
#    1575 # to avoid recursive import
# -> 1577 X, Y = check_pairwise_arrays(X, Y)
#    1579 X_normalized = normalize(X, copy=True)
#    1580 if X is Y:
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:149, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#      73 def check_pairwise_arrays(
#      74     X,
#      75     Y,
#    (...)
#      81     copy=False,
#      82 ):
#      83     """Set X and Y appropriately and checks inputs.
#      84
#      85     If Y is None, it is set as a pointer to X (i.e. not a copy).
#    (...)
#     147         If Y was None, safe_Y will be a pointer to X.
#     148     """
# --> 149     X, Y, dtype_float = _return_float_dtype(X, Y)
#     151     estimator = "check_pairwise_arrays"
#     152     if dtype is None:
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/sklearn/metrics/pairwise.py:55, in _return_float_dtype(X, Y)
#      50 """
#      51 1. If dtype of X and Y is float32, then dtype float32 is returned.
#      52 2. Else dtype float is returned.
#      53 """
#      54 if not issparse(X) and not isinstance(X, np.ndarray):
# ---> 55     X = np.asarray(X)
#      57 if Y is None:
#      58     Y_dtype = X.dtype
#
# KeyboardInterrupt:

# %%
src = 6727
dst_list = list(map(int, citation_network.out_edges(src)[1]))
# dst_list = [ 10012, 12323, 3888]

print(f"from node 0: [{dst_list}]")

for dst in dst_list:
    node1 = {'title': titles[src], 'abstract': abstracts[src], 'keywords': keywords[src], 'domain': domains[src]}
    node2 = {'title': titles[dst], 'abstract': abstracts[dst], 'keywords': keywords[dst], 'domain': domains[dst]}

    similarity = {}
    similarity['title'], similarity['abstract'], similarity['keyword'], similarity['domain'] = compute_similarity(node1, node2)
    hetro_similarity = compute_hetro_similarity(node1, node2)
    homo_similarity = compute_homo_similarity(node1, node2)
    
    normalised_title_similarity, normalised_abstract_similarity, normalised_keyword_similarity, normalised_domain_similarity = normalise(similarity, mean_for_normalise, std_for_normalise)
    
    print(f"HOMO: [{homo_similarity}]")
    print(f"HETRO: [{hetro_similarity}]")
    print(f"[{similarity['title']}, {similarity['abstract']}, {similarity['keyword']}, {similarity['domain']}]")
    print(f"[{normalised_title_similarity}, {normalised_abstract_similarity}, {normalised_keyword_similarity}, {-normalised_domain_similarity}]")
    print(f"SRC: {nodes.loc[int_to_id[src]]['title']}\nDST: {nodes.loc[int_to_id[dst]]['title']}")
    print(f"SRC: {nodes.loc[int_to_id[src]]['keywords']}\nDST: {nodes.loc[int_to_id[dst]]['keywords']}")
    print(f"SRC: {nodes.loc[int_to_id[src]]['fos']}\nDST: {nodes.loc[int_to_id[dst]]['fos']}\n")
# Out:
# from node 0: [[131321, 17561, 92871, 62313, 16087, 57746, 129680, 142120, 131815, 142170]]
# HOMO: [0.7681584894657135]
# HETRO: [0.4387723237276077]
# [0.676799476146698, 0.5793207883834839, 0.9246927499771118, 0.005660533905029297]
# [0.7434858656268578, 0.27657491496351805, 1.4307861909374398, 0.06546028151555407]
# SRC: Graph partitioning models for parallel computing
# DST: Multilevel Algorithms for Multi-Constraint Graph Partitioning
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['Graph partitioning', 'numerical simulations', 'parallel processing', 'Graph partitioning', 'numerical simulations', 'parallel processing']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Space partitioning', 'Mathematical optimization', 'Vertex (geometry)', 'Set partitioning in hierarchical trees', 'Computer science', 'Constraint graph', 'Algorithm', 'Theoretical computer science', 'Heuristics', 'Graph bandwidth', 'Graph partition', 'Partition (number theory)']
#
# HOMO: [0.7426816135644912]
# HETRO: [0.42013350427150725]
# [0.6196383237838745, 0.6815068125724792, 0.8296406865119934, 0.007325589656829834]
# [0.33471528894153496, 0.7990713055369586, 0.8947213525686312, 0.5025360269826386]
# SRC: Graph partitioning models for parallel computing
# DST: Partitioning Rectangular and Structurally Unsymmetric Sparse Matrices for Parallel Processing
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['matrix partitioning', 'iterative method', 'parallel computing', 'rectangular matrix', 'structurally unsymmetric matrix', 'bipartite graph']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Graph theory', 'Iterative method', 'Matrix (mathematics)', 'Bipartite graph', 'Parallel processing', 'Algorithm', 'Multiplication', 'Partition (number theory)', 'Sparse matrix', 'Mathematics']
#
# HOMO: [0.5495284348726273]
# HETRO: [0.3170316115021706]
# [0.5118250846862793, 0.20216569304466248, 0.8118534088134766, 0.009050488471984863]
# [-0.4362782634715099, -1.6518901326289501, 0.7944064956694363, 0.9553205266451393]
# SRC: Graph partitioning models for parallel computing
# DST: A Procedure for Placement of Standard-Cell VLSI Circuits
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['automatic placement', 'yields area', 'careful hand placement', 'placement procedure', 'Standard-Cell VLSI Circuits', 'standard cell', 'production use', 'automated design system', 'bipolar technology', 'external connection']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['NMOS logic', 'Computer science', 'Circuit design', 'CMOS', 'Electronic design automation', 'Standard cell', 'Graph partition', 'Computer engineering', 'Integrated circuit', 'Very-large-scale integration']
#
# HOMO: [0.817567664384842]
# HETRO: [0.46365022957324986]
# [0.7601720690727234, 0.775436282157898, 0.8024798631668091, 0.008010506629943848]
# [1.339699578636031, 1.2793503771259316, 0.7415425382881489, 0.6823261609064714]
# SRC: Graph partitioning models for parallel computing
# DST: A parallel bottom-up clustering algorithm with applications to circuit partitioning in VLSI design
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['parallel bottom-up', 'vlsi design', 'bottom up', 'application software', 'computer science', 'very large scale integration', 'random graph', 'clustering algorithms', 'algorithm design and analysis', 'terminology']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Canopy clustering algorithm', 'CURE data clustering algorithm', 'Algorithm design', 'Data stream clustering', 'Correlation clustering', 'Computer science', 'Parallel algorithm', 'Algorithm', 'Theoretical computer science', 'k-medoids', 'Cluster analysis']
#
# HOMO: [0.819413611292839]
# HETRO: [0.46651560962200167]
# [0.7507630586624146, 0.791878879070282, 0.8044134974479675, 0.0020992159843444824]
# [1.2724139055438, 1.363424472449232, 0.7524476497671224, -0.8693827009764034]
# SRC: Graph partitioning models for parallel computing
# DST: A multilevel algorithm for partitioning graphs
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['kernighan-lin algorithm', 'load balancing', 'multilevel algorithm', 'smallest graph', 'engineering problem', 'parallel computation', 'partitioning graph', 'smaller graph', 'entire algorithm', 'advanced method', 'original graph', 'high quality partition', 'graph partitioning', 'circuit placement', 'np-complete problem', 'load balance', 'concurrent computing', 'parallel computer', 'spectral method', 'data structures', 'sparse matrices', 'np complete problem', 'data structure', 'circuits']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Adjacency matrix', 'Strength of a graph', 'Modular decomposition', 'Graph power', 'Computer science', 'Algorithm', 'Matching (graph theory)', 'Independent set', 'Graph partition', 'Voltage graph']
#
# HOMO: [0.6780133783817291]
# HETRO: [0.3820107221603394]
# [0.5514218807220459, 0.6439158916473389, 0.7550567388534546, 0.008608698844909668]
# [-0.15311383306092766, 0.6068618458031033, 0.4740904857684112, 0.8393511181825644]
# SRC: Graph partitioning models for parallel computing
# DST: Hypergraph-Partitioning-Based Decomposition for Parallel Sparse-Matrix Vector Multiplication
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['graph partitioning', 'matrix multiplication', 'computational modeling', 'concurrent computing', 'computational', 'matrix decomposition', 'linear systems', 'parallel processing', 'sparse matrix', 'testing', 'parallel algorithms', 'sparse matrices', 'vectors']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Computer science', 'Matrix (mathematics)', 'Sparse matrix-vector multiplication', 'Matrix decomposition', 'Hypergraph', 'Theoretical computer science', 'Multiplication', 'Graph partition', 'Matrix multiplication', 'Sparse matrix']
#
# HOMO: [0.6747605264186859]
# HETRO: [0.3858564913272858]
# [0.603358268737793, 0.4726341962814331, 0.8332198858261108, 0.0063054561614990234]
# [0.21829343223341668, -0.2689337271263617, 0.9149069522480765, 0.23475183569324706]
# SRC: Graph partitioning models for parallel computing
# DST: A parallel hashed oct-tree N-body algorithm
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['N-body problems', 'parallel algorithms', 'physics computing', '512 processor Intel Touchstone Delta system', 'efficient adaptive N-body method', 'force calculations', 'hash table', 'machine arithmetic accuracy', 'memory locations', 'parallel hashed oct-tree N-body algorithm', 'parallel program', 'particle number', 'tree topology', 'wide-ranging applications']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Pointer (computer programming)', 'Computer science', 'Parallel algorithm', 'Iterative method', 'Parallel computing', 'Algorithm', 'Barnes–Hut simulation', 'Network topology', 'Time complexity', 'Hash table', 'Octree']
#
# HOMO: [0.7536694884300232]
# HETRO: [0.42422128319740293]
# [0.5270757675170898, 0.7372792959213257, 0.9190154075622559, 0.004856586456298828]
# [-0.32721764873747466, 1.0842465188243724, 1.3987676998806833, -0.14557525293442036]
# SRC: Graph partitioning models for parallel computing
# DST: A Fast and High Quality Multilevel Scheme for Partitioning Irregular Graphs
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['finite element computations', 'parallel computations', 'fill-reducing orderings', 'graph partitioning']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Discrete mathematics', 'Strength of a graph', 'Comparability graph', 'Modular decomposition', 'Computer science', 'Algorithm', 'Independent set', 'Graph product', 'Pathwidth', 'Graph partition', 'Partition refinement']
#
# HOMO: [0.6908627152442932]
# HETRO: [0.3938837945461273]
# [0.6546789407730103, 0.615464448928833, 0.6981480121612549, 0.00433802604675293]
# [0.5852975921663089, 0.4613842597534521, 0.15314250984967787, -0.28169692773533805]
# SRC: Graph partitioning models for parallel computing
# DST: Multilevel hypergraph partitioning: applications in VLSI domain
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['VLSI', 'circuit layout CAD', 'circuit optimisation', 'field programmable gate arrays', 'graph theory', 'integrated circuit layout', 'logic CAD', 'logic partitioning', 'multivalued logic circuits', 'VLSI domain', 'bisection', 'hyperedge cut', 'hypergraph coarsening strategies', 'multilevel hypergraph partitioning', 'partitioning algorithm', 'very large scale integration circuits']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Permission', 'Computer science', 'Hypergraph', 'Theoretical computer science', 'Integer programming', 'Application software', 'Very-large-scale integration', 'Covering problems', 'Integrated circuit layout', 'Graph theory', 'Vertex (geometry)', 'Supercomputer', 'Bisection', 'Constraint graph', 'Algorithm']
#
# HOMO: [0.6570886224508286]
# HETRO: [0.36856971979141234]
# [0.46798425912857056, 0.5936937928199768, 0.8336765170097351, 0.01053929328918457]
# [-0.7497925787854295, 0.3500667941061489, 0.9174822137702373, 1.346130548849429]
# SRC: Graph partitioning models for parallel computing
# DST: Improving the Run Time and Quality of Nested Dissection Ordering
# SRC: ['parallel computing', 'hypergraph partitioning', 'graph partitioning', 'parallel computer', 'parallel processing', 'mathematical model']
# DST: ['sparse matrix ordering', 'nested dissection', 'minimum degree', 'graph algorithms', 'graph partitioning']
# SRC: ['Discrete mathematics', 'Strength of a graph', 'Graph power', 'Computer science', 'Graph labeling', 'Quartic graph', 'Parallel computing', 'Theoretical computer science', 'Null graph', 'Graph partition', 'Graph (abstract data type)', 'Voltage graph']
# DST: ['Graph theory', 'Row and column spaces', 'Matrix calculus', 'Matrix (mathematics)', 'Nested dissection', 'Algorithm', 'Factorization', 'Graph partition', 'Mathematics', 'Sparse matrix']

# %%
# Create a DGL graph
citation_network = dgl.graph( (df['src'], df['dst']) )

citation_network.ndata['title'] = torch.FloatTensor(titles)
citation_network.ndata['abstract'] = torch.FloatTensor(abstracts)
citation_network.ndata['keyword'] = torch.FloatTensor(keywords)
citation_network.ndata['domain'] = torch.FloatTensor(domains)

# %%
citation_network.edata['weight'] = torch.FloatTensor(weight)

# %%
citation_network.edges()
# src_list, dst_list = citation_network.edges()
# for src, dst in zip(src_list, dst_list):
#     print(src, dst)
    # break
# Out:
# (tensor([ 72456,  81263,  42961,  ...,  30699, 111024,  88782]),
#  tensor([ 84909, 139661,  60423,  ..., 137791,  57453, 108899]))

# %%
# GAT Layer
class GATLayer(nn.Module):
    def __init__(self, in_dim, out_dim, num_heads=1):
        super(GATLayer, self).__init__()
        self.gatconv = GATConv(in_dim, out_dim, num_heads, allow_zero_in_degree=True)
        
    def forward(self, g, h):
        h = self.gatconv(g, h)
        return h.squeeze(1)

# GAT Model
class GATModel(nn.Module):
    def __init__(self, in_dim, hidden_dim, out_dim):
        super(GATModel, self).__init__()
        self.layer1 = GATLayer(in_dim, hidden_dim)
        self.layer2 = GATLayer(hidden_dim, out_dim)
        
    def forward(self, g, h):
        h = F.relu(self.layer1(g, h))
        h = self.layer2(g, h)
        return h

# %%
# Contrastive Loss
class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))
        return loss_contrastive

# %%
# Initialize lists to hold pairs and labels
pairs = []
labels = []

# Loop over edges in the graph to create pairs and labels
for u, v in zip(list(df['src']), list(df['des'])):
    node1 = {'title': titles[u], 'abstract': abstracts[u], 'keywords': keywords[u], 'domain': domains[u]}
    node2 = {'title': titles[v], 'abstract': abstracts[v], 'keywords': keywords[v], 'domain': domains[v]}
    
    similarity = compute_similarity(node1, node2)
    
    if similarity > 0.5:
        labels.append(0)
    else:
        labels.append(1)
        
    pairs.append((u, v))

# Convert pairs and labels to tensors
pairs = torch.LongTensor(pairs)
labels = torch.FloatTensor(labels)

# %%
torch.save(pairs, os.path.join(FILTERED_PATH, "gat", "pairs.pt"))
torch.save(labels, os.path.join(FILTERED_PATH, "gat", "labels.pt"))

# %%
# Initialize the model and loss
# INPUT: (Feature Dim, Hidden Dim, Output Dim)
model = GATModel(300, 128, 64)
loss_fn = ContrastiveLoss()

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
for epoch in range(50):
    model.train()
    
    # Forward pass
    h = torch.FloatTensor(citation_network.ndata['title'])
    output = model(citation_network, h)
    
    # Create output1 and output2 based on pairs
    output1 = output[pairs[:, 0]]
    output2 = output[pairs[:, 1]]
    
    # Compute contrastive loss
    loss = loss_fn(output1, output2, labels)
    
    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    print(f'Epoch {epoch}, Loss: {loss.item()}')
# Out:
# Epoch 0, Loss: 0.7327643036842346
# Epoch 1, Loss: 0.7099007964134216
# Epoch 2, Loss: 0.68633633852005
# Epoch 3, Loss: 0.6625358462333679
# Epoch 4, Loss: 0.6387461423873901
# Epoch 5, Loss: 0.6151835918426514
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 26
#      24 # Backward pass
#      25 optimizer.zero_grad()
# ---> 26 loss.backward()
#      27 optimizer.step()
#      29 print(f'Epoch {epoch}, Loss: {loss.item()}')
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# File ~/.conda/envs/msc/lib/python3.10/site-packages/torch/autograd/function.py:264, in BackwardCFunction.apply(self, *args)
#     263 class BackwardCFunction(_C._FunctionBase, FunctionCtx, _HookMixin):
# --> 264     def apply(self, *args):
#     265         # _forward_cls is defined by derived class
#     266         # The user should define either backward or vjp but never both.
#     267         backward_fn = self._forward_cls.backward  # type: ignore[attr-defined]
#     268         vjp_fn = self._forward_cls.vjp  # type: ignore[attr-defined]
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(os.path.join(FILTERED_PATH, "filtered_nodes.csv"))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148056    False
# 148057    False
# 148058    False
# 148059    False
# 148060    False
# Name: fos, Length: 148061, dtype: bool

# %%
df[df['fos'].isin(['computer science'])]
# Out:
# Empty DataFrame
# Columns: [_id, title, keywords, fos, abstract]
# Index: []

# %%
fos_list = list(map(eval, df['fos']))

# %%
eco = [ idx for idx, fos in enumerate(fos_list) if 'Economics' in fos ]
eco
# Out:
# [45,
#  59,
#  137,
#  163,
#  174,
#  253,
#  282,
#  311,
#  478,
#  493,
#  669,
#  725,
#  759,
#  860,
#  946,
#  948,
#  1166,
#  1284,
#  1294,
#  1299,
#  1326,
#  1493,
#  1622,
#  1800,
#  1869,
#  1934,
#  2211,
#  2274,
#  2316,
#  2415,
#  2439,
#  2742,
#  2932,
#  3071,
#  3198,
#  3475,
#  3783,
#  3891,
#  3905,
#  3942,
#  3952,
#  4079,
#  4192,
#  4315,
#  4389,
#  4487,
#  4539,
#  4544,
#  4620,
#  4653,
#  4685,
#  4747,
#  4820,
#  4870,
#  4909,
#  4968,
#  5098,
#  5172,
#  5489,
#  5729,
#  5733,
#  5946,
#  6090,
#  6278,
#  6302,
#  6477,
#  6585,
#  6612,
#  6673,
#  6818,
#  6862,
#  7091,
#  7258,
#  7272,
#  7379,
#  7380,
#  7395,
#  7742,
#  7791,
#  7974,
#  7980,
#  8097,
#  8107,
#  8308,
#  8366,
#  8462,
#  8602,
#  8606,
#  8619,
#  8667,
#  8911,
#  9261,
#  9333,
#  9384,
#  9403,
#  9430,
#  9526,
#  9658,
#  9738,
#  9973,
#  10182,
#  10493,
#  10877,
#  10963,
#  10974,
#  11318,
#  11365,
#  11376,
#  12010,
#  12118,
#  12238,
#  12555,
#  12570,
#  12604,
#  12611,
#  12625,
#  12632,
#  12966,
#  13085,
#  13113,
#  13258,
#  13844,
#  13878,
#  14035,
#  14260,
#  14292,
#  14384,
#  14414,
#  14479,
#  14765,
#  14795,
#  15216,
#  15369,
#  15399,
#  15587,
#  15683,
#  15745,
#  15825,
#  16029,
#  16109,
#  16309,
#  16461,
#  16589,
#  16727,
#  16818,
#  16859,
#  16952,
#  16994,
#  17006,
#  17057,
#  17106,
#  17149,
#  17546,
#  17563,
#  17624,
#  17649,
#  17660,
#  17960,
#  18007,
#  18115,
#  18126,
#  18391,
#  18407,
#  18507,
#  18611,
#  18643,
#  18728,
#  18771,
#  18887,
#  18989,
#  19134,
#  19179,
#  19248,
#  19377,
#  19379,
#  19797,
#  19825,
#  19903,
#  19943,
#  20223,
#  20337,
#  20397,
#  20399,
#  20430,
#  20462,
#  20564,
#  20798,
#  20809,
#  21013,
#  21039,
#  21069,
#  21143,
#  21286,
#  21292,
#  21661,
#  21789,
#  21883,
#  22010,
#  22080,
#  22202,
#  22234,
#  22264,
#  22326,
#  22349,
#  22430,
#  22442,
#  22591,
#  22830,
#  22964,
#  23150,
#  23246,
#  23701,
#  23921,
#  23988,
#  24004,
#  24070,
#  24374,
#  24521,
#  24601,
#  24609,
#  24611,
#  24733,
#  24758,
#  24779,
#  24786,
#  25005,
#  25007,
#  25384,
#  25788,
#  25810,
#  25821,
#  25862,
#  25911,
#  25922,
#  25968,
#  26066,
#  26161,
#  26162,
#  26187,
#  26250,
#  26516,
#  26556,
#  26579,
#  26600,
#  26624,
#  26629,
#  26639,
#  26658,
#  26771,
#  26776,
#  26811,
#  27019,
#  27204,
#  27318,
#  27330,
#  27396,
#  27409,
#  27561,
#  27599,
#  27741,
#  27763,
#  27771,
#  27806,
#  27827,
#  27988,
#  28325,
#  28403,
#  28434,
#  28447,
#  28470,
#  28504,
#  28778,
#  28791,
#  28965,
#  29040,
#  29046,
#  29088,
#  29089,
#  29107,
#  29137,
#  29167,
#  29245,
#  29575,
#  29588,
#  29748,
#  29881,
#  30014,
#  30208,
#  30517,
#  30561,
#  30621,
#  30746,
#  30844,
#  30872,
#  30914,
#  30981,
#  31012,
#  31068,
#  31115,
#  31133,
#  31312,
#  31439,
#  31470,
#  31584,
#  31666,
#  31676,
#  31710,
#  31740,
#  31742,
#  31757,
#  31850,
#  31903,
#  31908,
#  32122,
#  32307,
#  32405,
#  32567,
#  32579,
#  32628,
#  32657,
#  32677,
#  32845,
#  32863,
#  32970,
#  33317,
#  33452,
#  33824,
#  33871,
#  33886,
#  33904,
#  33911,
#  33920,
#  34209,
#  34214,
#  34382,
#  34469,
#  34507,
#  34581,
#  34779,
#  34790,
#  35179,
#  35194,
#  35229,
#  35533,
#  35590,
#  35649,
#  35765,
#  35770,
#  35806,
#  35959,
#  35995,
#  36093,
#  36286,
#  36288,
#  36727,
#  36743,
#  36967,
#  37255,
#  37456,
#  37470,
#  37494,
#  37553,
#  37583,
#  37604,
#  37671,
#  37877,
#  37894,
#  37977,
#  38193,
#  38228,
#  38290,
#  38388,
#  38427,
#  38479,
#  38702,
#  38759,
#  38806,
#  38922,
#  39048,
#  39234,
#  39274,
#  39385,
#  39391,
#  39450,
#  39714,
#  39761,
#  39870,
#  40020,
#  40125,
#  40479,
#  40533,
#  40561,
#  40655,
#  40683,
#  40702,
#  40804,
#  41001,
#  41215,
#  41235,
#  41277,
#  41392,
#  41755,
#  41848,
#  41952,
#  42070,
#  42126,
#  42175,
#  42334,
#  42341,
#  42376,
#  42459,
#  42480,
#  42525,
#  42641,
#  42731,
#  42755,
#  42946,
#  42960,
#  42961,
#  42994,
#  43093,
#  43160,
#  43191,
#  43254,
#  43351,
#  43612,
#  43708,
#  43791,
#  43831,
#  44240,
#  44286,
#  44310,
#  44359,
#  44485,
#  44503,
#  44543,
#  44632,
#  44655,
#  44710,
#  44846,
#  44868,
#  45029,
#  45052,
#  45160,
#  45234,
#  45308,
#  45427,
#  45486,
#  45555,
#  45580,
#  45615,
#  45688,
#  45884,
#  45916,
#  46032,
#  46138,
#  46438,
#  46440,
#  46567,
#  46614,
#  46718,
#  46786,
#  46895,
#  46897,
#  47038,
#  47040,
#  47159,
#  47275,
#  47292,
#  47354,
#  47463,
#  47841,
#  47997,
#  48136,
#  48379,
#  48408,
#  48437,
#  48471,
#  48791,
#  48850,
#  48851,
#  48860,
#  49067,
#  49169,
#  49260,
#  49345,
#  49396,
#  49469,
#  49474,
#  49530,
#  49678,
#  50052,
#  50194,
#  50228,
#  50333,
#  50390,
#  50480,
#  50505,
#  50670,
#  50679,
#  50769,
#  50804,
#  50877,
#  50918,
#  51043,
#  51174,
#  51209,
#  51221,
#  51250,
#  51696,
#  51757,
#  51823,
#  51892,
#  52234,
#  52267,
#  52268,
#  52273,
#  52306,
#  52345,
#  52361,
#  52419,
#  52438,
#  52894,
#  52991,
#  53019,
#  53315,
#  53318,
#  53518,
#  53615,
#  53704,
#  53714,
#  53852,
#  54071,
#  54088,
#  54125,
#  54225,
#  54344,
#  54444,
#  54568,
#  54601,
#  54725,
#  54960,
#  54971,
#  55139,
#  55291,
#  55400,
#  55467,
#  55636,
#  55744,
#  55765,
#  55940,
#  56048,
#  56086,
#  56101,
#  56104,
#  56131,
#  56145,
#  56186,
#  56329,
#  56338,
#  56417,
#  56696,
#  56789,
#  56993,
#  57120,
#  57169,
#  57342,
#  57358,
#  57535,
#  57710,
#  57720,
#  57775,
#  57844,
#  57976,
#  58003,
#  58040,
#  58078,
#  58126,
#  58216,
#  58231,
#  58340,
#  58378,
#  58447,
#  58449,
#  58480,
#  58500,
#  58537,
#  58640,
#  58679,
#  58698,
#  58778,
#  58802,
#  58818,
#  58831,
#  58906,
#  58993,
#  59243,
#  59332,
#  59423,
#  59508,
#  59516,
#  59530,
#  59621,
#  59707,
#  59788,
#  59794,
#  59922,
#  60078,
#  60573,
#  60601,
#  60788,
#  60892,
#  61029,
#  61079,
#  61086,
#  61115,
#  61155,
#  61220,
#  61247,
#  61412,
#  61433,
#  61484,
#  61543,
#  61666,
#  62031,
#  62059,
#  62066,
#  62312,
#  62320,
#  62454,
#  62939,
#  63017,
#  63104,
#  63165,
#  63223,
#  63227,
#  63370,
#  63407,
#  63426,
#  63541,
#  63616,
#  63874,
#  64091,
#  64138,
#  64376,
#  64433,
#  64500,
#  64561,
#  64675,
#  64717,
#  64787,
#  64799,
#  64877,
#  64928,
#  65030,
#  65239,
#  65338,
#  65362,
#  65367,
#  65832,
#  65935,
#  65951,
#  66156,
#  66178,
#  66240,
#  66298,
#  66310,
#  66387,
#  66426,
#  66496,
#  66543,
#  66545,
#  66626,
#  66662,
#  66860,
#  66862,
#  66879,
#  66916,
#  67027,
#  67146,
#  67361,
#  67376,
#  67557,
#  67606,
#  67619,
#  67713,
#  67870,
#  67922,
#  67974,
#  68034,
#  68039,
#  68102,
#  68361,
#  68391,
#  68441,
#  68465,
#  68509,
#  68610,
#  68866,
#  68867,
#  68905,
#  69051,
#  69123,
#  69184,
#  69188,
#  69395,
#  69425,
#  69457,
#  69544,
#  69588,
#  69685,
#  69697,
#  69701,
#  69790,
#  69805,
#  69845,
#  69924,
#  70262,
#  70273,
#  70292,
#  70301,
#  70404,
#  70834,
#  70865,
#  70890,
#  70921,
#  71093,
#  71189,
#  71366,
#  71502,
#  71570,
#  71627,
#  71689,
#  71725,
#  71791,
#  71911,
#  71938,
#  72035,
#  72482,
#  72639,
#  72645,
#  72904,
#  73247,
#  73332,
#  73369,
#  73816,
#  73926,
#  73954,
#  74280,
#  74350,
#  74374,
#  74471,
#  74700,
#  74798,
#  74879,
#  74909,
#  74945,
#  75116,
#  75117,
#  75129,
#  75135,
#  75194,
#  75460,
#  75632,
#  76142,
#  76165,
#  76317,
#  76486,
#  76590,
#  76608,
#  76626,
#  76763,
#  76842,
#  76910,
#  76939,
#  77061,
#  77294,
#  77375,
#  77380,
#  77479,
#  77492,
#  77547,
#  77548,
#  77759,
#  77807,
#  77984,
#  78193,
#  78313,
#  78437,
#  78462,
#  78497,
#  78528,
#  78628,
#  78667,
#  78687,
#  78842,
#  78958,
#  78962,
#  79029,
#  79298,
#  79326,
#  79359,
#  79802,
#  79864,
#  79865,
#  79878,
#  79941,
#  80520,
#  80699,
#  80828,
#  80885,
#  81048,
#  81063,
#  81215,
#  81227,
#  81387,
#  81569,
#  81690,
#  81695,
#  81720,
#  81779,
#  81831,
#  81855,
#  81875,
#  82075,
#  82081,
#  82313,
#  82339,
#  82355,
#  82358,
#  82494,
#  82530,
#  82539,
#  82609,
#  82635,
#  82714,
#  82751,
#  82797,
#  82855,
#  82871,
#  82936,
#  83111,
#  83165,
#  83352,
#  83474,
#  83614,
#  83617,
#  83713,
#  83726,
#  83732,
#  83805,
#  84089,
#  84105,
#  84126,
#  84148,
#  84170,
#  84209,
#  84306,
#  84397,
#  84526,
#  84595,
#  84657,
#  84691,
#  84782,
#  84850,
#  84877,
#  85087,
#  85104,
#  85144,
#  85171,
#  85275,
#  85341,
#  85449,
#  85503,
#  85565,
#  85587,
#  85942,
#  86147,
#  86191,
#  86506,
#  86697,
#  86768,
#  86890,
#  87062,
#  87207,
#  87262,
#  87298,
#  87600,
#  87649,
#  87687,
#  87695,
#  87751,
#  87780,
#  87815,
#  87836,
#  87909,
#  88047,
#  88098,
#  88126,
#  88148,
#  88158,
#  88358,
#  88475,
#  88623,
#  88757,
#  88798,
#  88828,
#  88909,
#  88912,
#  89000,
#  89108,
#  89201,
#  89207,
#  89233,
#  89326,
#  89415,
#  89446,
#  89476,
#  89684,
#  89721,
#  89769,
#  89774,
#  89829,
#  89964,
#  90113,
#  90117,
#  90160,
#  90177,
#  90186,
#  90327,
#  90335,
#  90612,
#  90661,
#  90706,
#  90760,
#  90926,
#  90994,
#  91022,
#  91247,
#  91283,
#  91314,
#  91499,
#  91611,
#  91628,
#  91732,
#  91823,
#  91909,
#  92127,
#  92147,
#  92235,
#  92288,
#  92766,
#  92857,
#  92900,
#  93001,
#  93103,
#  93206,
#  93277,
#  94038,
#  94190,
#  94252,
#  94793,
#  94856,
#  94919,
#  94927,
#  95101,
#  95127,
#  95135,
#  95195,
#  95276,
#  95314,
#  95793,
#  95798,
#  95843,
#  95878,
#  95886,
#  96141,
#  96144,
#  96154,
#  96233,
#  96295,
#  96353,
#  96449,
#  96469,
#  96530,
#  96733,
#  96909,
#  96951,
#  96953,
#  96984,
#  96993,
#  97142,
#  97150,
#  97167,
#  97244,
#  97257,
#  97262,
#  97599,
#  97853,
#  97881,
#  ...]

# %%
eco_df = df.iloc[eco, :]
eco_df
# Out:
#                              _id  \
# 45      53e997d1b7602d9701fc3662
# 59      53e997d7b7602d9701fcbff2
# 137     53e997e3b7602d9701fd8bdf
# 163     53e997e4b7602d9701fda4d3
# 174     53e997e4b7602d9701fdb822
# ...                          ...
# 147576  5c88eb284895d9cbc6a0bb16
# 147675  5c8b3aaa4895d9cbc6780378
# 147877  5cc6fdb36558b90bfa00923c
# 147911  5ccd92896558b90bfa49fd11
# 147912  5ccd92896558b90bfa49fd14
#
#                                                     title  \
# 45      Computerized loan origination systems: an indu...
# 59      An EPQ-based inventory model for exponentially...
# 137     A jump to default extended CEV model: an appli...
# 163     Production trade-offs and weight restrictions ...
# 174     DEA Malmquist productivity measure: New insigh...
# ...                                                   ...
# 147576  Privacy, economics, and price discrimination o...
# 147675  Deep learning with long short-term memory netw...
# 147877  Horizontal cooperation among freight carriers:...
# 147911          LIBOR and swap market models and measures
# 147912      Efficient hedging: Cost versus shortfall risk
#
#                                                  keywords  \
# 45      ['electronic market', 'electronic coordination...
# 59      ['partial trade credit', 'optimal replenishmen...
# 137     ['equity derivatives', 'default', 'implied vol...
# 163                            ['data envelope analysis']
# 174     ['Data envelopment analysis', 'Efficiency', 'M...
# ...                                                   ...
# 147576  ['increasing ability', 'public agendum', 'priv...
# 147675  ['Finance', 'Statistical arbitrage', 'LSTM', '...
# 147877  ['logistics', 'communications technology', 'ma...
# 147911  ['self-financing trading strategies', 'stochas...
# 147912  ['stochastic volatility', 'convex duality', 'r...
#
#                                                       fos  \
# 45      ['Financial intermediary', 'Incomplete contrac...
# 59      ['Minimization problem', 'Economics', 'Economi...
# 137     ['Econometrics', 'Credit derivative', 'Economi...
# 163     ['Information system', 'Economics', 'Mathemati...
# 174     ['Isoquant', 'Efficiency', 'Econometrics', 'Ec...
# ...                                                   ...
# 147576  ['Internet privacy', 'Economics', 'Reservation...
# 147675  ['Statistical arbitrage', 'Econometrics', 'Eco...
# 147877  ['Profit sharing', 'Economics', 'Benefice', 'O...
# 147911  ['Econometrics', 'Economics', 'Financial econo...
# 147912  ['Stochastic volatility', 'Economics', 'Mathem...
#
#                                                  abstract
# 45      Much has been written in recent years about th...
# 59      The main purpose of this paper is to investiga...
# 137     We consider the problem of developing a ßexibl...
# 163     In this paper we suggest two equivalent ways i...
# 174     Data envelopment analysis (DEA) measures the r...
# ...                                                   ...
# 147576  The rapid erosion of privacy poses numerous pu...
# 147675  •Application of long short-term memory network...
# 147877  In modern transportation systems, the potentia...
# 147911  .   A self-contained theory is presented for p...
# 147912  .   An investor faced with a contingent claim ...
#
# [1350 rows x 5 columns]

# %%
eco_df.to_csv('eco_papers.csv')
